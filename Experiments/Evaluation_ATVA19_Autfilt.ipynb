# %% [markdown]
# ## Evaluation of translators to deterministic automata with additional optimizations
#
# This notebook contains evaluation of `ltl3tela -D1`, `ltl2tgba -DG`, Delag and Rabinizer 4 where we applied the Spot postprocessing procedures (using the `autfilt` tool) to output of Delag and Rabinizer 4.

# %%
from ltlcross_runner import LtlcrossRunner
from IPython.display import display
import pandas as pd
import spot
import sys
import re
spot.setup(show_default='.a')
pd.options.display.float_format = '{: .0f}'.format
pd.options.display.latex.multicolumn_format = 'c'
from tables_utils import split_cols, high_min, high_max, highlight_by_level
from tables_utils import fix_latex, fix_type, fix_tool
from tables_utils import cummulative_to_latex

# %%
rerun = False

# %%
# %%bash
# ltl3tela -v
# ltl2tgba --version
# delag --version
# ltl2dgra --version # Rabinizer 4
# autfilt --version
# Out:
# LTL3TELA 2.0.0 (using Spot 2.7.4)
# ltl2tgba (spot) 2.7.4
#
# Copyright (C) 2019  Laboratoire de Recherche et Développement de l'Epita.
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
# Name: owl
# Version: 18.06
# Name: owl
# Version: 18.06
# autfilt (spot) 2.7.4
#
# Copyright (C) 2019  Laboratoire de Recherche et Développement de l'Epita.
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.

# %%
def generate(n=1000,func=(lambda x: True),filename=None,priorities='',ap=['a','b','c','d','e']):
    if filename is None:
        file_h = sys.stdout
    else:
        file_h = open(filename,'w')
    f = spot.randltl(ap,
                     ltl_priorities=priorities,
                     simplify=3,tree_size=15).relabel_bse(spot.Abc)
    i = 0
    printed = set()
    while(i < n):
        form = next(f)
        if form in printed:
            continue
        if func(form) and not form.is_tt() and not form.is_ff():
            print(form,file=file_h)
            printed.add(form)
            i += 1

# %%
f_rand = 'formulae/atva19/rand.ltl'
f_patterns = 'formulae/atva19/patterns.ltl'
# generate(1000, filename = f_rand)

# %% [markdown]
# ### Deterministic automata

# %%
d_tools = {
    "ltl3tela-D1": "ltl3tela -D1 -f %f > %O",
    "ltl2tgba-DG": "ltl2tgba -DG %f > %O",
    "delag": "delag %f | autfilt -G --deterministic --high > %O",
    "rabinizer4": "ltl2dgra %f | autfilt -G --deterministic --high > %O"
}
d_order = ["ltl3tela-D1", "ltl2tgba-DG", "delag", "rabinizer4"]
d_cols = ["states", "edges", "acc"]

# %%
d_csv_rand = 'formulae/atva19/det.rand.autfilt.csv'
d_data_rand = LtlcrossRunner(d_tools, formula_files = [f_rand], res_filename = d_csv_rand, cols = d_cols)
if rerun:
    d_data_rand.run_ltlcross(automata = False, timeout = '60')
d_data_rand.parse_results()

# %%
det_rand = d_data_rand.cummulative(col = d_cols).unstack(level = 0).loc[d_order, d_cols]
det_rand
# Out:
# column       states  edges   acc
# tool
# ltl3tela-D1    5934  18520  1268
# ltl2tgba-DG    6799  24131  1575
# delag          6468  24168  2203
# rabinizer4     6450  24454  1915

# %%
d_csv_patterns = 'formulae/atva19/det.patterns.autfilt.csv'
d_data_patterns = LtlcrossRunner(d_tools, formula_files = [f_patterns], res_filename = d_csv_patterns, cols = d_cols)
if rerun:
    d_data_patterns.run_ltlcross(automata = False, timeout = '60')
d_data_patterns.parse_results()

# %%
det_to = pd.DataFrame(d_data_patterns.get_error_count(),columns=['TO.literature'])
det_err = pd.DataFrame(d_data_patterns.get_error_count('parse error',False),columns=['PE.literature'])
det_lit = d_data_patterns.cummulative(col = d_cols).unstack(level = 0).loc[d_order, d_cols]
det_lit = pd.concat([det_lit,det_to,det_err],axis=1,join='inner',sort=False)
det_lit
# Out:
#              states  edges  acc  TO.literature  PE.literature
# tool
# ltl3tela-D1    2536  10641  454             39              0
# ltl2tgba-DG    3905  26643  652             20              0
# delag          2732  18142  774             11              0
# rabinizer4     2766  11091  749             12              0

# %%
to = d_data_rand.exit_status
to[to != "ok"].dropna(how='all')
# Out:
# Empty DataFrame
# Columns: [delag, ltl2tgba-DG, ltl3tela-D1, rabinizer4]
# Index: []

# %%
det_tmp = pd.merge(det_rand, det_lit, suffixes=('.random','.literature'),on='tool')
det_tmp
# Out:
#              states.random  edges.random  acc.random  states.literature  \
# tool
# ltl3tela-D1           5934         18520        1268               2536
# ltl2tgba-DG           6799         24131        1575               3905
# delag                 6468         24168        2203               2732
# rabinizer4            6450         24454        1915               2766
#
#              edges.literature  acc.literature  TO.literature  PE.literature
# tool
# ltl3tela-D1             10641             454             39              0
# ltl2tgba-DG             26643             652             20              0
# delag                   18142             774             11              0
# rabinizer4              11091             749             12              0

# %%
det = split_cols(det_tmp,'.').swaplevel(axis=1)
det
# Out:
#             random              literature
#             states  edges   acc     states  edges  acc  TO PE
# tool
# ltl3tela-D1   5934  18520  1268       2536  10641  454  39  0
# ltl2tgba-DG   6799  24131  1575       3905  26643  652  20  0
# delag         6468  24168  2203       2732  18142  774  11  0
# rabinizer4    6450  24454  1915       2766  11091  749  12  0

# %%
rerun = False

# %% [markdown]
# ### Formulae excluded from the evaluation

# %%
d_fails = d_data_patterns.values[d_data_patterns.values.isnull().any(axis = 1)]['states']\
    .join(d_data_patterns.exit_status, lsuffix = '.states', rsuffix = '.response')
for tool in d_order:
    d_fails[tool] = d_fails[tool + '.states'].combine_first(d_fails[tool + '.response'])
d_fails_out = d_fails[d_order]
d_fails_out
# Out:
# tool                                                       ltl3tela-D1  \
# form_id formula
# 103     GFz <-> (GFa1 & GFa2 & GFa3 & GFa4)                          1
# 104     GFz <-> (GFa1 & GFa2 & GFa3 & GFa4 & GFa5)             timeout
# 129     (FGp2 | GFp1) & (FGp3 | GFp2) & (FGp4 | GFp3) &...           1
# 181     G(!p0 | X(!p0 | X(!p0 | X(!p0 | X(!p0 | X(!p0 |...     timeout
# 193     c & X(a1 | b1 | d) & G(c -> !d) & G((a1 | b1) -...     timeout
# 194     c & X(a1 | b1 | d) & G(c -> !d) & G(((a1 | b1) ...     timeout
# 195     c & X(a1 | b1 | d) & G(c -> !d) & G(((a1 | b1) ...     timeout
# 196     c & X(a1 | b1 | d) & G(c -> !d) & G(((a1 | b1) ...     timeout
# 198     c & X(d | y) & G(y -> X((a | b) & Xz)) & G(z ->...     timeout
# 199     c & G(!(a & b) & !(a & c) & !(a & d) & !(a & y)...     timeout
# 200     c & G(!(a & b) & !(a & c) & !(a & d) & !(a & y)...     timeout
# 201     c & G(!(a & b) & !(a & c) & !(a & d) & !(a & y)...     timeout
# 203     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...     timeout
# 204     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...     timeout
# 205     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...     timeout
# 206     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...     timeout
# 236     FG(a | b) | FG(!a | Xb) | FG(a | XXb) | FG(!a |...     timeout
# 240     (FGa4 & GFb4) | (((FGa2 & GFb2) | (FGa0 & GFb0 ...     timeout
# 241     (FGa5 & GFb5) | (((FGa3 & GFb3) | (((FGa1 & GFb...           1
# 245     ((FGa3 & GFb3) | (((FGa1 & GFb1) | FGa0 | GFb0)...     timeout
# 246     ((FGa4 & GFb4) | (((FGa2 & GFb2) | (FGa0 & GFb0...           1
# 296     !b & m & X!b & XX!b & XXX!b & XXXX!b & G(m -> (...     timeout
# 301     !b & m & G((!b & m) -> (!c & XXXXXb)) & G((b & ...     timeout
# 342     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U Xb)))                timeout
# 343     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXb)))               timeout
# 344     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXb)))              timeout
# 345     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXXb)))             timeout
# 346     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXXXb)))            timeout
# 347     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U Xb))))      timeout
# 348     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXb))))     timeout
# 349     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXb...     timeout
# 350     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXX...     timeout
# 351     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXX...     timeout
# 352     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...     timeout
# 353     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...     timeout
# 354     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...     timeout
# 355     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...     timeout
# 356     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...     timeout
# 360     (GFa1 & GFa2 & GFa3 & GFa4) -> (GFb1 & GFb2 & G...     timeout
# 361     (GFa1 & GFa2 & GFa3 & GFa4 & GFa5) -> (GFb1 & G...     timeout
# 365     (GFa1 | FGb1) & (GFa2 | FGb2) & (GFa3 | FGb3) &...     timeout
# 366     (GFa1 | FGb1) & (GFa2 | FGb2) & (GFa3 | FGb3) &...     timeout
# 388     G(p1 -> (p1 U (p2 & (p2 U (p3 & (p3 U (p4 & (p4...          28
# 389     G(p1 -> (p1 U (p2 & (p2 U (p3 & (p3 U (p4 & (p4...     timeout
#
# tool                                                       ltl2tgba-DG  \
# form_id formula
# 103     GFz <-> (GFa1 & GFa2 & GFa3 & GFa4)                          1
# 104     GFz <-> (GFa1 & GFa2 & GFa3 & GFa4 & GFa5)                   1
# 129     (FGp2 | GFp1) & (FGp3 | GFp2) & (FGp4 | GFp3) &...           1
# 181     G(!p0 | X(!p0 | X(!p0 | X(!p0 | X(!p0 | X(!p0 |...          12
# 193     c & X(a1 | b1 | d) & G(c -> !d) & G((a1 | b1) -...     timeout
# 194     c & X(a1 | b1 | d) & G(c -> !d) & G(((a1 | b1) ...     timeout
# 195     c & X(a1 | b1 | d) & G(c -> !d) & G(((a1 | b1) ...     timeout
# 196     c & X(a1 | b1 | d) & G(c -> !d) & G(((a1 | b1) ...     timeout
# 198     c & X(d | y) & G(y -> X((a | b) & Xz)) & G(z ->...     timeout
# 199     c & G(!(a & b) & !(a & c) & !(a & d) & !(a & y)...     timeout
# 200     c & G(!(a & b) & !(a & c) & !(a & d) & !(a & y)...     timeout
# 201     c & G(!(a & b) & !(a & c) & !(a & d) & !(a & y)...     timeout
# 203     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...         106
# 204     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...        3057
# 205     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...     timeout
# 206     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...     timeout
# 236     FG(a | b) | FG(!a | Xb) | FG(a | XXb) | FG(!a |...          32
# 240     (FGa4 & GFb4) | (((FGa2 & GFb2) | (FGa0 & GFb0 ...           1
# 241     (FGa5 & GFb5) | (((FGa3 & GFb3) | (((FGa1 & GFb...           1
# 245     ((FGa3 & GFb3) | (((FGa1 & GFb1) | FGa0 | GFb0)...           1
# 246     ((FGa4 & GFb4) | (((FGa2 & GFb2) | (FGa0 & GFb0...           1
# 296     !b & m & X!b & XX!b & XXX!b & XXXX!b & G(m -> (...         160
# 301     !b & m & G((!b & m) -> (!c & XXXXXb)) & G((b & ...         160
# 342     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U Xb)))                   2781
# 343     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXb)))                  2782
# 344     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXb)))                 2783
# 345     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXXb)))                2784
# 346     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXXXb)))               2785
# 347     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U Xb))))      timeout
# 348     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXb))))     timeout
# 349     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXb...     timeout
# 350     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXX...     timeout
# 351     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXX...     timeout
# 352     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...     timeout
# 353     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...     timeout
# 354     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...     timeout
# 355     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...     timeout
# 356     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...     timeout
# 360     (GFa1 & GFa2 & GFa3 & GFa4) -> (GFb1 & GFb2 & G...           1
# 361     (GFa1 & GFa2 & GFa3 & GFa4 & GFa5) -> (GFb1 & G...           1
# 365     (GFa1 | FGb1) & (GFa2 | FGb2) & (GFa3 | FGb3) &...           1
# 366     (GFa1 | FGb1) & (GFa2 | FGb2) & (GFa3 | FGb3) &...           1
# 388     G(p1 -> (p1 U (p2 & (p2 U (p3 & (p3 U (p4 & (p4...          51
# 389     G(p1 -> (p1 U (p2 & (p2 U (p3 & (p3 U (p4 & (p4...         298
#
# tool                                                            delag  \
# form_id formula
# 103     GFz <-> (GFa1 & GFa2 & GFa3 & GFa4)                         1
# 104     GFz <-> (GFa1 & GFa2 & GFa3 & GFa4 & GFa5)                  1
# 129     (FGp2 | GFp1) & (FGp3 | GFp2) & (FGp4 | GFp3) &...          1
# 181     G(!p0 | X(!p0 | X(!p0 | X(!p0 | X(!p0 | X(!p0 |...         12
# 193     c & X(a1 | b1 | d) & G(c -> !d) & G((a1 | b1) -...         82
# 194     c & X(a1 | b1 | d) & G(c -> !d) & G(((a1 | b1) ...       2240
# 195     c & X(a1 | b1 | d) & G(c -> !d) & G(((a1 | b1) ...    timeout
# 196     c & X(a1 | b1 | d) & G(c -> !d) & G(((a1 | b1) ...    timeout
# 198     c & X(d | y) & G(y -> X((a | b) & Xz)) & G(z ->...        147
# 199     c & G(!(a & b) & !(a & c) & !(a & d) & !(a & y)...    timeout
# 200     c & G(!(a & b) & !(a & c) & !(a & d) & !(a & y)...    timeout
# 201     c & G(!(a & b) & !(a & c) & !(a & d) & !(a & y)...    timeout
# 203     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...    timeout
# 204     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...    timeout
# 205     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...    timeout
# 206     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...    timeout
# 236     FG(a | b) | FG(!a | Xb) | FG(a | XXb) | FG(!a |...         32
# 240     (FGa4 & GFb4) | (((FGa2 & GFb2) | (FGa0 & GFb0 ...          1
# 241     (FGa5 & GFb5) | (((FGa3 & GFb3) | (((FGa1 & GFb...          1
# 245     ((FGa3 & GFb3) | (((FGa1 & GFb1) | FGa0 | GFb0)...          1
# 246     ((FGa4 & GFb4) | (((FGa2 & GFb2) | (FGa0 & GFb0...          1
# 296     !b & m & X!b & XX!b & XXX!b & XXXX!b & G(m -> (...        160
# 301     !b & m & G((!b & m) -> (!c & XXXXXb)) & G((b & ...        160
# 342     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U Xb)))                     3
# 343     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXb)))                    4
# 344     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXb)))                   5
# 345     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXXb)))                  6
# 346     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXXXb)))                 7
# 347     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U Xb))))   exit code
# 348     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXb))))  exit code
# 349     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXb...  exit code
# 350     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXX...  exit code
# 351     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXX...  exit code
# 352     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...  exit code
# 353     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...  exit code
# 354     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...  exit code
# 355     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...  exit code
# 356     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...  exit code
# 360     (GFa1 & GFa2 & GFa3 & GFa4) -> (GFb1 & GFb2 & G...          1
# 361     (GFa1 & GFa2 & GFa3 & GFa4 & GFa5) -> (GFb1 & G...          1
# 365     (GFa1 | FGb1) & (GFa2 | FGb2) & (GFa3 | FGb3) &...          1
# 366     (GFa1 | FGb1) & (GFa2 | FGb2) & (GFa3 | FGb3) &...          1
# 388     G(p1 -> (p1 U (p2 & (p2 U (p3 & (p3 U (p4 & (p4...    timeout
# 389     G(p1 -> (p1 U (p2 & (p2 U (p3 & (p3 U (p4 & (p4...    timeout
#
# tool                                                       rabinizer4
# form_id formula
# 103     GFz <-> (GFa1 & GFa2 & GFa3 & GFa4)                 exit code
# 104     GFz <-> (GFa1 & GFa2 & GFa3 & GFa4 & GFa5)          exit code
# 129     (FGp2 | GFp1) & (FGp3 | GFp2) & (FGp4 | GFp3) &...  exit code
# 181     G(!p0 | X(!p0 | X(!p0 | X(!p0 | X(!p0 | X(!p0 |...         12
# 193     c & X(a1 | b1 | d) & G(c -> !d) & G((a1 | b1) -...         82
# 194     c & X(a1 | b1 | d) & G(c -> !d) & G(((a1 | b1) ...    timeout
# 195     c & X(a1 | b1 | d) & G(c -> !d) & G(((a1 | b1) ...    timeout
# 196     c & X(a1 | b1 | d) & G(c -> !d) & G(((a1 | b1) ...    timeout
# 198     c & X(d | y) & G(y -> X((a | b) & Xz)) & G(z ->...    timeout
# 199     c & G(!(a & b) & !(a & c) & !(a & d) & !(a & y)...    timeout
# 200     c & G(!(a & b) & !(a & c) & !(a & d) & !(a & y)...    timeout
# 201     c & G(!(a & b) & !(a & c) & !(a & d) & !(a & y)...    timeout
# 203     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...        106
# 204     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...    timeout
# 205     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...    timeout
# 206     G(!(a & b) & !(a & c) & !(a & d) & !(b & c) & !...    timeout
# 236     FG(a | b) | FG(!a | Xb) | FG(a | XXb) | FG(!a |...        420
# 240     (FGa4 & GFb4) | (((FGa2 & GFb2) | (FGa0 & GFb0 ...          1
# 241     (FGa5 & GFb5) | (((FGa3 & GFb3) | (((FGa1 & GFb...    timeout
# 245     ((FGa3 & GFb3) | (((FGa1 & GFb1) | FGa0 | GFb0)...  exit code
# 246     ((FGa4 & GFb4) | (((FGa2 & GFb2) | (FGa0 & GFb0...    timeout
# 296     !b & m & X!b & XX!b & XXX!b & XXXX!b & G(m -> (...        160
# 301     !b & m & G((!b & m) -> (!c & XXXXXb)) & G((b & ...        160
# 342     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U Xb)))                     3
# 343     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXb)))                    4
# 344     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXb)))                   5
# 345     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXXb)))                  6
# 346     GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXXXb)))                 7
# 347     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U Xb))))           3
# 348     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXb))))          4
# 349     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXb...          5
# 350     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXX...          6
# 351     GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GFa0 U XXXX...          7
# 352     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...          3
# 353     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...          4
# 354     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...          5
# 355     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...          6
# 356     GFa5 U G(GFa4 U G(GFa3 U G(GFa2 U G(GFa1 U G(GF...          7
# 360     (GFa1 & GFa2 & GFa3 & GFa4) -> (GFb1 & GFb2 & G...  exit code
# 361     (GFa1 & GFa2 & GFa3 & GFa4 & GFa5) -> (GFb1 & G...  exit code
# 365     (GFa1 | FGb1) & (GFa2 | FGb2) & (GFa3 | FGb3) &...  exit code
# 366     (GFa1 | FGb1) & (GFa2 | FGb2) & (GFa3 | FGb3) &...  exit code
# 388     G(p1 -> (p1 U (p2 & (p2 U (p3 & (p3 U (p4 & (p4...         22
# 389     G(p1 -> (p1 U (p2 & (p2 U (p3 & (p3 U (p4 & (p4...         58

# %%
def large_diff(res, tools, threshold):
    df = res.values.dropna()['states']
    df['diff'] = df.loc[:, tools].max(axis = 1) - df.loc[:, tools].min(axis = 1)
    return df[df['diff'] > threshold][tools]

# %%
large_diff(d_data_patterns, d_tools, 20)
# Out:
# tool                                                        ltl2tgba-DG  \
# form_id formula
# 72      G(p0 -> (((p1 & X(!p2 U p3)) -> X(!p2 U (p3 & F...           16
# 77      G(p0 -> ((p1 -> (!p2 U (!p2 & p3 & X(!p2 U p4))...           11
# 82      G(p0 -> ((p1 -> (!p2 U (!p2 & p3 & !p4 & X((!p2...           11
# 108     GF(a <-> XXXXa)                                              16
# 109     GF(a <-> XXXXXa)                                             32
# 172     G((!(p1 <-> Xp1) | !(p0 <-> Xp0) | !(p2 <-> Xp2...           81
# 235     FG(a | b) | FG(!a | Xb) | FG(a | XXb) | FG(!a |...           16
# 337     GFa2 U G(GFa1 U G(GFa0 U Xb))                               257
# 338     GFa2 U G(GFa1 U G(GFa0 U XXb))                              258
# 339     GFa2 U G(GFa1 U G(GFa0 U XXXb))                             259
# 340     GFa2 U G(GFa1 U G(GFa0 U XXXXb))                            260
# 341     GFa2 U G(GFa1 U G(GFa0 U XXXXXb))                           261
# 387     G(p1 -> (p1 U (p2 & (p2 U (p3 & (p3 U p4))))))               12
#
# tool                                                        ltl3tela-D1  \
# form_id formula
# 72      G(p0 -> (((p1 & X(!p2 U p3)) -> X(!p2 U (p3 & F...            6
# 77      G(p0 -> ((p1 -> (!p2 U (!p2 & p3 & X(!p2 U p4))...           10
# 82      G(p0 -> ((p1 -> (!p2 U (!p2 & p3 & !p4 & X((!p2...           11
# 108     GF(a <-> XXXXa)                                              16
# 109     GF(a <-> XXXXXa)                                             32
# 172     G((!(p1 <-> Xp1) | !(p0 <-> Xp0) | !(p2 <-> Xp2...           34
# 235     FG(a | b) | FG(!a | Xb) | FG(a | XXb) | FG(!a |...           16
# 337     GFa2 U G(GFa1 U G(GFa0 U Xb))                                11
# 338     GFa2 U G(GFa1 U G(GFa0 U XXb))                               12
# 339     GFa2 U G(GFa1 U G(GFa0 U XXXb))                              13
# 340     GFa2 U G(GFa1 U G(GFa0 U XXXXb))                             14
# 341     GFa2 U G(GFa1 U G(GFa0 U XXXXXb))                            15
# 387     G(p1 -> (p1 U (p2 & (p2 U (p3 & (p3 U p4))))))               11
#
# tool                                                        delag  rabinizer4
# form_id formula
# 72      G(p0 -> (((p1 & X(!p2 U p3)) -> X(!p2 U (p3 & F...     62          34
# 77      G(p0 -> ((p1 -> (!p2 U (!p2 & p3 & X(!p2 U p4))...     43          11
# 82      G(p0 -> ((p1 -> (!p2 U (!p2 & p3 & !p4 & X((!p2...     82          11
# 108     GF(a <-> XXXXa)                                        16          65
# 109     GF(a <-> XXXXXa)                                       32         161
# 172     G((!(p1 <-> Xp1) | !(p0 <-> Xp0) | !(p2 <-> Xp2...     33          33
# 235     FG(a | b) | FG(!a | Xb) | FG(a | XXb) | FG(!a |...     16          83
# 337     GFa2 U G(GFa1 U G(GFa0 U Xb))                           3           3
# 338     GFa2 U G(GFa1 U G(GFa0 U XXb))                          4           4
# 339     GFa2 U G(GFa1 U G(GFa0 U XXXb))                         5           5
# 340     GFa2 U G(GFa1 U G(GFa0 U XXXXb))                        6           6
# 341     GFa2 U G(GFa1 U G(GFa0 U XXXXXb))                       7           7
# 387     G(p1 -> (p1 U (p2 & (p2 U (p3 & (p3 U p4))))))         80           9

# %%
large_diff(d_data_rand, d_tools, 10)
# Out:
# tool                                                        ltl2tgba-DG  \
# form_id formula
# 23      Fa U (F(!b | (c & XXb) | (!c & XX!b)) R d)                   16
# 46      ((a M b) U Xc) W Gd                                          62
# 57      GF(a | (b R XFc))                                            15
# 58      (a & G((XFb & (c U Xd)) | (XG!b & (!c R X!d))))...           20
# 84      G(G(a & (b | (c M Xd))) | (F!a & F(!b & (!c W X...           32
# 118     XF(((a M Gb) & ((XFc & (d | Fe)) | (!d & XG!c &...          116
# 143     F((a & X((!b | XG!c) U !c)) | (!a & X((b & XFc)...           13
# 195     (!a | GFb) U (Gb | (a W Gc))                                 24
# 215     G(Ga | Xb | F(c & Gd))                                       30
# 274     G(a M ((b & (!c | X(!c R XX!d))) | (!b & c & X(...           27
# 291     G(Fa | ((F!b | Xc) & (((a & !d) | (!a & d)) R c...           71
# 319     F((a & ((((b & Gc) | (!b & F!c)) & (c | X(c R b...            8
# 330     G(a | Gb) R ((c & X(a W (d & Gc))) | (!c & X(!a...           55
# 342     XG((a U !b) & (b U X((c & GF!d) | (!c & FGd))))              29
# 344     G(a | (F!b & (Xc | F!d)) | (X!c & G(b & d)))                 15
# 399     GF(((a W b) & ((!c & G!a) | (c & Fa))) | ((!a M...            6
# 414     G((a | (b W c)) M G(Fc U Xd))                                97
# 420     (a & GF((!b & G(!c | (!a U X!c))) | (b & F(c & ...           71
# 424     GF((!a W ((b & G!a) | (!b & Fa))) W c)                       15
# 451     F(((!a | b) & (c | (Fd & F!a) | G(a & !d))) | (...           19
# 530     F(Xa & Fb & Fc) W (a R d)                                    47
# 590     X((a W !b) R (a M c)) W (Gd R b)                             22
# 596     GF(Xa & G(Gb | F!a))                                         19
# 613     ((a & F!b) | (!a & Gb)) W ((a U Xc) M d)                     26
# 638     (!a W Xb) U G((Xa & (!c M !d)) | (X!a & (c W d)))            20
# 692     F((Ga & X(b & c) & ((a & Fb) R d)) | ((F!a | X(...           12
# 703     (a & ((b & F!c) | (!b & Gc))) W ((d & ((e M c) ...           65
# 805     F((a W (((!b & !c) | (b & c)) U ((d & X!d) | (!...           15
# 808     G((a & F!a) | (b & (((!c & X!b) | (c & Xb)) M X...           45
# 884     G((a | Fb) U Xa)                                             16
# 902     Xa M ((!b & Fc) | (b & G!c) | (d R (b | Fe)))                46
# 953     (Ga & ((Gb M Xa) | (Gc R !b))) | (F!a & (F!b W ...           24
#
# tool                                                        ltl3tela-D1  \
# form_id formula
# 23      Fa U (F(!b | (c & XXb) | (!c & XX!b)) R d)                    7
# 46      ((a M b) U Xc) W Gd                                          12
# 57      GF(a | (b R XFc))                                             2
# 58      (a & G((XFb & (c U Xd)) | (XG!b & (!c R X!d))))...           17
# 84      G(G(a & (b | (c M Xd))) | (F!a & F(!b & (!c W X...           11
# 118     XF(((a M Gb) & ((XFc & (d | Fe)) | (!d & XG!c &...           79
# 143     F((a & X((!b | XG!c) U !c)) | (!a & X((b & XFc)...            6
# 195     (!a | GFb) U (Gb | (a W Gc))                                 14
# 215     G(Ga | Xb | F(c & Gd))                                       16
# 274     G(a M ((b & (!c | X(!c R XX!d))) | (!b & c & X(...           27
# 291     G(Fa | ((F!b | Xc) & (((a & !d) | (!a & d)) R c...            7
# 319     F((a & ((((b & Gc) | (!b & F!c)) & (c | X(c R b...            6
# 330     G(a | Gb) R ((c & X(a W (d & Gc))) | (!c & X(!a...           50
# 342     XG((a U !b) & (b U X((c & GF!d) | (!c & FGd))))              18
# 344     G(a | (F!b & (Xc | F!d)) | (X!c & G(b & d)))                 10
# 399     GF(((a W b) & ((!c & G!a) | (c & Fa))) | ((!a M...            5
# 414     G((a | (b W c)) M G(Fc U Xd))                                13
# 420     (a & GF((!b & G(!c | (!a U X!c))) | (b & F(c & ...           27
# 424     GF((!a W ((b & G!a) | (!b & Fa))) W c)                        2
# 451     F(((!a | b) & (c | (Fd & F!a) | G(a & !d))) | (...           11
# 530     F(Xa & Fb & Fc) W (a R d)                                    16
# 590     X((a W !b) R (a M c)) W (Gd R b)                             18
# 596     GF(Xa & G(Gb | F!a))                                          5
# 613     ((a & F!b) | (!a & Gb)) W ((a U Xc) M d)                     26
# 638     (!a W Xb) U G((Xa & (!c M !d)) | (X!a & (c W d)))            20
# 692     F((Ga & X(b & c) & ((a & Fb) R d)) | ((F!a | X(...           12
# 703     (a & ((b & F!c) | (!b & Gc))) W ((d & ((e M c) ...           61
# 805     F((a W (((!b & !c) | (b & c)) U ((d & X!d) | (!...           15
# 808     G((a & F!a) | (b & (((!c & X!b) | (c & Xb)) M X...           15
# 884     G((a | Fb) U Xa)                                              5
# 902     Xa M ((!b & Fc) | (b & G!c) | (d R (b | Fe)))                36
# 953     (Ga & ((Gb M Xa) | (Gc R !b))) | (F!a & (F!b W ...           23
#
# tool                                                        delag  rabinizer4
# form_id formula
# 23      Fa U (F(!b | (c & XXb) | (!c & XX!b)) R d)             21           8
# 46      ((a M b) U Xc) W Gd                                    18          13
# 57      GF(a | (b R XFc))                                       1           1
# 58      (a & G((XFb & (c U Xd)) | (XG!b & (!c R X!d))))...     28          21
# 84      G(G(a & (b | (c M Xd))) | (F!a & F(!b & (!c W X...     12          18
# 118     XF(((a M Gb) & ((XFc & (d | Fe)) | (!d & XG!c &...    125         125
# 143     F((a & X((!b | XG!c) U !c)) | (!a & X((b & XFc)...     21           8
# 195     (!a | GFb) U (Gb | (a W Gc))                            7           7
# 215     G(Ga | Xb | F(c & Gd))                                 18          22
# 274     G(a M ((b & (!c | X(!c R XX!d))) | (!b & c & X(...     17          58
# 291     G(Fa | ((F!b | Xc) & (((a & !d) | (!a & d)) R c...     15          93
# 319     F((a & ((((b & Gc) | (!b & F!c)) & (c | X(c R b...     50           7
# 330     G(a | Gb) R ((c & X(a W (d & Gc))) | (!c & X(!a...     61          73
# 342     XG((a U !b) & (b U X((c & GF!d) | (!c & FGd))))         7           9
# 344     G(a | (F!b & (Xc | F!d)) | (X!c & G(b & d)))           14          24
# 399     GF(((a W b) & ((!c & G!a) | (c & Fa))) | ((!a M...      7         173
# 414     G((a | (b W c)) M G(Fc U Xd))                           5           3
# 420     (a & GF((!b & G(!c | (!a U X!c))) | (b & F(c & ...     13          21
# 424     GF((!a W ((b & G!a) | (!b & Fa))) W c)                  1           1
# 451     F(((!a | b) & (c | (Fd & F!a) | G(a & !d))) | (...     30          16
# 530     F(Xa & Fb & Fc) W (a R d)                              55          18
# 590     X((a W !b) R (a M c)) W (Gd R b)                       16          28
# 596     GF(Xa & G(Gb | F!a))                                    1           1
# 613     ((a & F!b) | (!a & Gb)) W ((a U Xc) M d)               48          26
# 638     (!a W Xb) U G((Xa & (!c M !d)) | (X!a & (c W d)))      47          36
# 692     F((Ga & X(b & c) & ((a & Fb) R d)) | ((F!a | X(...     22           9
# 703     (a & ((b & F!c) | (!b & Gc))) W ((d & ((e M c) ...    162         115
# 805     F((a W (((!b & !c) | (b & c)) U ((d & X!d) | (!...     26          11
# 808     G((a & F!a) | (b & (((!c & X!b) | (c & Xb)) M X...     45          54
# 884     G((a | Fb) U Xa)                                        5           3
# 902     Xa M ((!b & Fc) | (b & G!c) | (d R (b | Fe)))          70          37
# 953     (Ga & ((Gb M Xa) | (Gc R !b))) | (F!a & (F!b W ...     35          23
